# %%
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Load data

df1 = pd.read_csv('../data/MAARS_all_Fri_Apr_04_14h_CEST_2014.csv', header = 0, sep="\t")

# %%
df1.head()
# Out:
#         sample_id clinical_group anatomical_location  \
# 0  MAARS_3_018_02             AD     posterior_thigh
# 1  MAARS_3_018_01             AD     posterior_thigh
# 2  MAARS_3_018_03             AD     posterior_thigh
# 3  MAARS_3_018_04             AD     posterior_thigh
# 4  MAARS_3_082_02             AD     posterior_thigh
#
#   anatomical_location_label lesional MAARS_identifier Institution  CUSTOM_Age  \
# 0                        PT  NON_LES      MAARS_3_018          UH          25
# 1                        PT      LES      MAARS_3_018          UH          25
# 2                        PT      LES      MAARS_3_018          UH          25
# 3                        PT  NON_LES      MAARS_3_018          UH          25
# 4                        PT  NON_LES      MAARS_3_082          UH          62
#
#   Gender  Known_Allergies_v2..Pseudo_Drug_Allergy  ...  \
# 0   Male                                    False  ...
# 1   Male                                    False  ...
# ...

# %%
# drop anatomical_location 
df1 = df1.drop(columns = ['anatomical_location'])

# %%
df1[["sample_id","clinical_group","anatomical_location_label"]]
# Out:
#            sample_id clinical_group anatomical_location_label
# 0     MAARS_3_018_02             AD                        PT
# 1     MAARS_3_018_01             AD                        PT
# 2     MAARS_3_018_03             AD                        PT
# 3     MAARS_3_018_04             AD                        PT
# 4     MAARS_3_082_02             AD                        PT
# ...              ...            ...                       ...
# 1312  MAARS_2_067_04            PSO                        LB
# 1313  MAARS_3_080_02            PSO                        LB
# 1314  MAARS_3_080_01            PSO                        LB
# 1315  MAARS_3_080_03            PSO                        LB
# 1316  MAARS_3_080_04            PSO                        LB
#
# [1317 rows x 3 columns]

# %%
to_dummys=['clinical_group'	anatomical_location]

# %%
def explore_column(df, column):
    print("Colonne :",column)
    print("Unique values: ",df[column].unique())
    print("Nombre de modalités :",len(set(df[column])))

# %%
explore_column(df1, column='clinical_group')
# Out:
# Colonne : clinical_group
# Unique values:  ['AD' 'CTRL' 'PSO']
# Nombre de modalités : 3

# %%
explore_column(df1, column='lesional')
# Out:
# Colonne : lesional
# Unique values:  ['NON_LES' 'LES']
# Nombre de modalités : 2

# %%
explore_column(df1, column='Institution')
# Out:
# Colonne : Institution
# Unique values:  ['UH' 'HHU' 'KINGS']
# Nombre de modalités : 3

# %%
len(set(df1.anatomical_location))
# Out:
# 5

# %%
df1.anatomical_location_label.unique()
# Out:
# array(['PT', 'UB', 'LB', 'T', 'B'], dtype=object)

# %%
df1.anatomical_location_label.unique()

# %%
df1.dtypes
# Out:
# sample_id                                                       object
# clinical_group                                                  object
# anatomical_location                                             object
# anatomical_location_label                                       object
# lesional                                                        object
# MAARS_identifier                                                object
# Institution                                                     object
# CUSTOM_Age                                                       int64
# Gender                                                          object
# Known_Allergies_v2..Pseudo_Drug_Allergy                           bool
# Known_Allergies_v2..House_dust_mite                               bool
# Known_Allergies_v2..Food                                          bool
# Known_Allergies_v2..Pollen                                        bool
# ...

# %%
df1["CUSTOM_Fam._hist._Atopic_dermatitis"].isnull().sum()
# Out:
# 512

# %%
pandas_profiling.ProfileReport(df1)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
